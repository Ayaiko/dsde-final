# %%
# Reload modules to pick up changes
import importlib
import pipeline.features
import pipeline.preprocess

importlib.reload(pipeline.features)
importlib.reload(pipeline.preprocess)

from pipeline.features import *
from pipeline.preprocess import *

print("✓ Modules reloaded")
# Out:
# ✓ Modules reloaded

# %%
import pandas as pd
from pipeline.extract import load_traffy_data, load_single_location_weather, load_bangkok_air_quality
from pipeline.utils import split_coordinates, clean_traffy_data
from pipeline.preprocess import parse_type_column, filter_empty_types, drop_missing_weather
from pipeline.features import prepare_features

# %%
# Load and clean Traffy data through pipeline
df_traffy = load_traffy_data('data/raw/bangkok_traffy.csv')
df_traffy = clean_traffy_data(df_traffy)
df_traffy = split_coordinates(df_traffy)

print(f"✓ Cleaned Traffy data: {df_traffy.shape}")
df_traffy.head()
# Out:
# Loading Traffy data from: data/raw/bangkok_traffy.csv
# ✓ Loaded 787,026 records
# ✓ Loaded 787,026 records
# ✓ Cleaned Traffy data: (651600, 9)
# ✓ Cleaned Traffy data: (651600, 9)
#                   type                                            comment  \
# 0  {น้ำท่วม,ร้องเรียน}  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 1              {สะพาน}    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 2        {น้ำท่วม,ถนน}  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 3                   {}                        หน้าปากซอย ลาดพร้าววังหิน26
# 4                   {}  ยังไม่มีหน่วยงานไหนมาดูแลครับ รถจะเชี่ยวหลายคน...
#
#                coords subdistrict  district       province  \
# 0  100.66709,13.67891     หนองบอน    ประเวศ  กรุงเทพมหานคร
# 1  100.52649,13.72060     ยานนาวา      สาทร  กรุงเทพมหานคร
# 2  100.59165,13.82280    ลาดพร้าว  ลาดพร้าว  กรุงเทพมหานคร
# 3  100.59131,13.80910    ลาดพร้าว  ลาดพร้าว  กรุงเทพมหานคร
# 4  100.50848,13.77832       ดุสิต     ดุสิต  กรุงเทพมหานคร
#
#                        timestamp  longitude  latitude
# 0  2021-09-19 14:56:08.924992+00  100.66709  13.67891
# 1  2021-09-26 05:03:52.594898+00  100.52649  13.72060
# 2  2021-12-09 12:29:08.408763+00  100.59165  13.82280
# 3  2021-12-13 05:53:36.861064+00  100.59131  13.80910
# 4  2021-12-17 08:46:02.610983+00  100.50848  13.77832

# %%
# Load weather data
df_weather = load_single_location_weather('data/raw/open-meteo-13.74N100.50E9m.csv')

# Parse timestamps and create date columns
df_traffy['timestamp'] = pd.to_datetime(df_traffy['timestamp'], format='mixed', utc=True)
df_traffy['date'] = df_traffy['timestamp'].dt.date
df_traffy['date'] = pd.to_datetime(df_traffy['date'])

df_weather['date'] = pd.to_datetime(df_weather['time']).dt.date
df_weather['date'] = pd.to_datetime(df_weather['date'])

# Aggregate weather to daily average
df_weather_daily = df_weather.groupby('date').mean(numeric_only=True).reset_index()

print(f"✓ Weather aggregated: {df_weather_daily.shape}")
# Out:
# ✓ Weather aggregated: (1279, 10)

# %%
# Load air quality data
df_air = load_bangkok_air_quality('data/processed/bangkok-air-quality.csv')
print(f"✓ Loaded {len(df_air):,} air quality records")

# Merge weather on date
df = df_traffy.merge(df_weather_daily, on='date', how='left')
print(f"✓ Merged with weather: {df.shape}")

# Merge air quality data
df = df.merge(df_air, on='date', how='left')
print(f"✓ Merged with air quality: {df.shape}")
# Out:
# ✓ Loaded 4,351 air quality records
# ✓ Merged with weather: (651600, 19)
# ✓ Merged with air quality: (651600, 23)

# %%
# Apply preprocessing pipeline
df = parse_type_column(df)
df = filter_empty_types(df)
df = drop_missing_weather(df)

print(f"✓ After preprocessing: {df.shape}")
df.info()
# Out:
# ✓ After preprocessing: (540633, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 540633 entries, 0 to 540632
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   type                           540633 non-null  object
#  1   comment                        540633 non-null  object
#  2   coords                         540633 non-null  object
#  3   subdistrict                    540633 non-null  object
#  4   district                       540633 non-null  object
#  5   province                       540633 non-null  object
#  6   timestamp                      540633 non-null  datetime64[ns, UTC]
#  7   longitude                      540633 non-null  float64
#  8   latitude                       540633 non-null  float64
#  9   date                           540633 non-null  datetime64[ns]
#  10  temperature_2m (°C)            540633 non-null  float64
#  11  dew_point_2m (°C)              540633 non-null  float64
#  12  relative_humidity_2m (%)       540633 non-null  float64
#  13  rain (mm)                      540633 non-null  float64
#  14  vapour_pressure_deficit (kPa)  540633 non-null  float64
#  15  cloud_cover (%)                540633 non-null  float64
#  16  wind_direction_10m (°)         540633 non-null  float64
#  17  surface_pressure (hPa)         540633 non-null  float64
#  18  wind_speed_10m (km/h)          540633 non-null  float64
#  19   pm25                          540236 non-null  object
#  20   pm10                          540236 non-null  object
#  21   o3                            540236 non-null  object
#  22   no2                           540236 non-null  object
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(11), object(10)
# memory usage: 94.9+ MB

# %%
# Check actual column names for air quality
air_cols = [col for col in df.columns if any(x in col.lower() for x in ['pm2.5', 'pm10', 'o3', 'no2', 'pm25'])]
print("Air quality column names:")
print(air_cols)
# Out:
# Air quality column names:
# [' pm25', ' pm10', ' o3', ' no2']

# %%
# Drop rows without air quality data
# Find actual air quality column names (they have leading spaces)
air_quality_cols = [col for col in df.columns if any(x in col.strip().lower() for x in ['pm2.5', 'pm25', 'pm10', 'o3', 'no2'])]
print(f"Air quality columns: {air_quality_cols}")
print(f"Before dropping nulls: {len(df):,} records")
df = df.dropna(subset=air_quality_cols)
print(f"After dropping nulls: {len(df):,} records")
print(f"✓ Dropped records without complete air quality data")
# Out:
# Air quality columns: [' pm25', ' pm10', ' o3', ' no2']
# Before dropping nulls: 540,633 records
# After dropping nulls: 540,236 records
# ✓ Dropped records without complete air quality data

# %%
# Apply feature engineering
df = prepare_features(df)
print(f"✓ Features prepared: {df.shape}")
df.info()
# Out:
# ============================================================
# FEATURE ENGINEERING
# ============================================================
#
# Extracting time features...
# hello
# Encoding cyclical features...
# Encoding districts...
#   ✓ Encoded 50 districts
#
# ✓ Feature engineering complete
#   Final shape: (540236, 83)
#   New features: hour, day_of_week, month, season, cyclical encodings, districts
# ✓ Features prepared: (540236, 83)
#   ✓ Encoded 50 districts
#
# ✓ Feature engineering complete
#   Final shape: (540236, 83)
#   New features: hour, day_of_week, month, season, cyclical encodings, districts
# ✓ Features prepared: (540236, 83)
# <class 'pandas.core.frame.DataFrame'>
# Index: 540236 entries, 0 to 540632
# Data columns (total 83 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   type                           540236 non-null  object
#  1   comment                        540236 non-null  object
#  2   coords                         540236 non-null  object
#  3   subdistrict                    540236 non-null  object
#  4   district                       540236 non-null  object
#  5   province                       540236 non-null  object
#  6   timestamp                      540236 non-null  datetime64[ns, UTC]
#  7   longitude                      540236 non-null  float64
#  8   latitude                       540236 non-null  float64
#  9   date                           540236 non-null  datetime64[ns]
#  10  temperature_2m (°C)            540236 non-null  float64
#  11  dew_point_2m (°C)              540236 non-null  float64
#  12  relative_humidity_2m (%)       540236 non-null  float64
#  13  rain (mm)                      540236 non-null  float64
#  14  vapour_pressure_deficit (kPa)  540236 non-null  float64
#  15  cloud_cover (%)                540236 non-null  float64
#  16  wind_direction_10m (°)         540236 non-null  float64
#  17  surface_pressure (hPa)         540236 non-null  float64
#  18  wind_speed_10m (km/h)          540236 non-null  float64
#  19   pm25                          540236 non-null  object
#  20   pm10                          540236 non-null  object
#  21   o3                            540236 non-null  object
#  22   no2                           540236 non-null  object
#  23  timestamp_col                  540236 non-null  datetime64[ns, UTC]
#  24  hour                           540236 non-null  int32
#  25  day_of_week                    540236 non-null  int32
#  26  month                          540236 non-null  int32
#  27  hour_sin                       540236 non-null  float64
#  28  hour_cos                       540236 non-null  float64
#  29  day_sin                        540236 non-null  float64
#  30  day_cos                        540236 non-null  float64
#  31  month_sin                      540236 non-null  float64
#  32  month_cos                      540236 non-null  float64
#  33  district_คลองสาน               540236 non-null  bool
#  34  district_คลองสามวา             540236 non-null  bool
#  35  district_คลองเตย               540236 non-null  bool
#  36  district_คันนายาว              540236 non-null  bool
#  37  district_จตุจักร               540236 non-null  bool
#  38  district_จอมทอง                540236 non-null  bool
#  39  district_ดอนเมือง              540236 non-null  bool
#  40  district_ดินแดง                540236 non-null  bool
#  41  district_ดุสิต                 540236 non-null  bool
#  42  district_ตลิ่งชัน              540236 non-null  bool
#  43  district_ทวีวัฒนา              540236 non-null  bool
#  44  district_ทุ่งครุ               540236 non-null  bool
#  45  district_ธนบุรี                540236 non-null  bool
#  46  district_บางกอกน้อย            540236 non-null  bool
#  47  district_บางกอกใหญ่            540236 non-null  bool
#  48  district_บางกะปิ               540236 non-null  bool
#  49  district_บางขุนเทียน           540236 non-null  bool
#  50  district_บางคอแหลม             540236 non-null  bool
#  51  district_บางซื่อ               540236 non-null  bool
#  52  district_บางนา                 540236 non-null  bool
#  53  district_บางบอน                540236 non-null  bool
#  54  district_บางพลัด               540236 non-null  bool
#  55  district_บางรัก                540236 non-null  bool
#  56  district_บางเขน                540236 non-null  bool
#  57  district_บางแค                 540236 non-null  bool
#  58  district_บึงกุ่ม               540236 non-null  bool
#  59  district_ปทุมวัน               540236 non-null  bool
#  60  district_ประเวศ                540236 non-null  bool
#  61  district_ป้อมปราบศัตรูพ่าย     540236 non-null  bool
#  62  district_พญาไท                 540236 non-null  bool
#  63  district_พระนคร                540236 non-null  bool
#  64  district_พระโขนง               540236 non-null  bool
#  65  district_ภาษีเจริญ             540236 non-null  bool
#  66  district_มีนบุรี               540236 non-null  bool
#  67  district_ยานนาวา               540236 non-null  bool
#  68  district_ราชเทวี               540236 non-null  bool
#  69  district_ราษฎร์บูรณะ           540236 non-null  bool
#  70  district_ลาดกระบัง             540236 non-null  bool
#  71  district_ลาดพร้าว              540236 non-null  bool
#  72  district_วังทองหลาง            540236 non-null  bool
#  73  district_วัฒนา                 540236 non-null  bool
#  74  district_สวนหลวง               540236 non-null  bool
#  75  district_สะพานสูง              540236 non-null  bool
#  76  district_สัมพันธวงศ์           540236 non-null  bool
#  77  district_สาทร                  540236 non-null  bool
#  78  district_สายไหม                540236 non-null  bool
#  79  district_หนองจอก               540236 non-null  bool
#  80  district_หนองแขม               540236 non-null  bool
#  81  district_หลักสี่               540236 non-null  bool
#  82  district_ห้วยขวาง              540236 non-null  bool
# dtypes: bool(50), datetime64[ns, UTC](2), datetime64[ns](1), float64(17), int32(3), object(10)
# memory usage: 159.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 540236 entries, 0 to 540632
# Data columns (total 83 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   type                           540236 non-null  object
#  1   comment                        540236 non-null  object
#  2   coords                         540236 non-null  object
#  3   subdistrict                    540236 non-null  object
#  4   district                       540236 non-null  object
#  5   province                       540236 non-null  object
#  6   timestamp                      540236 non-null  datetime64[ns, UTC]
#  7   longitude                      540236 non-null  float64
#  8   latitude                       540236 non-null  float64
#  9   date                           540236 non-null  datetime64[ns]
#  10  temperature_2m (°C)            540236 non-null  float64
#  11  dew_point_2m (°C)              540236 non-null  float64
#  12  relative_humidity_2m (%)       540236 non-null  float64
#  13  rain (mm)                      540236 non-null  float64
#  14  vapour_pressure_deficit (kPa)  540236 non-null  float64
#  15  cloud_cover (%)                540236 non-null  float64
#  16  wind_direction_10m (°)         540236 non-null  float64
#  17  surface_pressure (hPa)         540236 non-null  float64
#  18  wind_speed_10m (km/h)          540236 non-null  float64
#  19   pm25                          540236 non-null  object
#  20   pm10                          540236 non-null  object
#  21   o3                            540236 non-null  object
#  22   no2                           540236 non-null  object
#  23  timestamp_col                  540236 non-null  datetime64[ns, UTC]
#  24  hour                           540236 non-null  int32
#  25  day_of_week                    540236 non-null  int32
#  26  month                          540236 non-null  int32
#  27  hour_sin                       540236 non-null  float64
#  28  hour_cos                       540236 non-null  float64
#  29  day_sin                        540236 non-null  float64
#  30  day_cos                        540236 non-null  float64
#  31  month_sin                      540236 non-null  float64
#  32  month_cos                      540236 non-null  float64
#  33  district_คลองสาน               540236 non-null  bool
#  34  district_คลองสามวา             540236 non-null  bool
#  35  district_คลองเตย               540236 non-null  bool
#  36  district_คันนายาว              540236 non-null  bool
#  37  district_จตุจักร               540236 non-null  bool
#  38  district_จอมทอง                540236 non-null  bool
#  39  district_ดอนเมือง              540236 non-null  bool
#  40  district_ดินแดง                540236 non-null  bool
#  41  district_ดุสิต                 540236 non-null  bool
#  42  district_ตลิ่งชัน              540236 non-null  bool
#  43  district_ทวีวัฒนา              540236 non-null  bool
#  44  district_ทุ่งครุ               540236 non-null  bool
#  45  district_ธนบุรี                540236 non-null  bool
#  46  district_บางกอกน้อย            540236 non-null  bool
#  47  district_บางกอกใหญ่            540236 non-null  bool
#  48  district_บางกะปิ               540236 non-null  bool
#  49  district_บางขุนเทียน           540236 non-null  bool
#  50  district_บางคอแหลม             540236 non-null  bool
#  51  district_บางซื่อ               540236 non-null  bool
#  52  district_บางนา                 540236 non-null  bool
#  53  district_บางบอน                540236 non-null  bool
#  54  district_บางพลัด               540236 non-null  bool
#  55  district_บางรัก                540236 non-null  bool
#  56  district_บางเขน                540236 non-null  bool
#  57  district_บางแค                 540236 non-null  bool
#  58  district_บึงกุ่ม               540236 non-null  bool
#  59  district_ปทุมวัน               540236 non-null  bool
#  60  district_ประเวศ                540236 non-null  bool
#  61  district_ป้อมปราบศัตรูพ่าย     540236 non-null  bool
#  62  district_พญาไท                 540236 non-null  bool
#  63  district_พระนคร                540236 non-null  bool
#  64  district_พระโขนง               540236 non-null  bool
#  65  district_ภาษีเจริญ             540236 non-null  bool
#  66  district_มีนบุรี               540236 non-null  bool
#  67  district_ยานนาวา               540236 non-null  bool
#  68  district_ราชเทวี               540236 non-null  bool
#  69  district_ราษฎร์บูรณะ           540236 non-null  bool
#  70  district_ลาดกระบัง             540236 non-null  bool
#  71  district_ลาดพร้าว              540236 non-null  bool
#  72  district_วังทองหลาง            540236 non-null  bool
#  73  district_วัฒนา                 540236 non-null  bool
#  74  district_สวนหลวง               540236 non-null  bool
#  75  district_สะพานสูง              540236 non-null  bool
#  76  district_สัมพันธวงศ์           540236 non-null  bool
#  77  district_สาทร                  540236 non-null  bool
#  78  district_สายไหม                540236 non-null  bool
#  79  district_หนองจอก               540236 non-null  bool
#  80  district_หนองแขม               540236 non-null  bool
#  81  district_หลักสี่               540236 non-null  bool
#  82  district_ห้วยขวาง              540236 non-null  bool
# dtypes: bool(50), datetime64[ns, UTC](2), datetime64[ns](1), float64(17), int32(3), object(10)
# memory usage: 159.7+ MB

# %%
df.columns
# Out:
# Index(['type', 'comment', 'coords', 'subdistrict', 'district', 'province',
#        'timestamp', 'longitude', 'latitude', 'date', 'temperature_2m (°C)',
#        'dew_point_2m (°C)', 'relative_humidity_2m (%)', 'rain (mm)',
#        'vapour_pressure_deficit (kPa)', 'cloud_cover (%)',
#        'wind_direction_10m (°)', 'surface_pressure (hPa)',
#        'wind_speed_10m (km/h)', ' pm25', ' pm10', ' o3', ' no2',
#        'timestamp_col', 'hour', 'day_of_week', 'month', 'hour_sin', 'hour_cos',
#        'day_sin', 'day_cos', 'month_sin', 'month_cos', 'district_คลองสาน',
#        'district_คลองสามวา', 'district_คลองเตย', 'district_คันนายาว',
#        'district_จตุจักร', 'district_จอมทอง', 'district_ดอนเมือง',
#        'district_ดินแดง', 'district_ดุสิต', 'district_ตลิ่งชัน',
#        'district_ทวีวัฒนา', 'district_ทุ่งครุ', 'district_ธนบุรี',
#        'district_บางกอกน้อย', 'district_บางกอกใหญ่', 'district_บางกะปิ',
#        'district_บางขุนเทียน', 'district_บางคอแหลม', 'district_บางซื่อ',
#        'district_บางนา', 'district_บางบอน', 'district_บางพลัด',
#        'district_บางรัก', 'district_บางเขน', 'district_บางแค',
#        'district_บึงกุ่ม', 'district_ปทุมวัน', 'district_ประเวศ',
#        'district_ป้อมปราบศัตรูพ่าย', 'district_พญาไท', 'district_พระนคร',
#        'district_พระโขนง', 'district_ภาษีเจริญ', 'district_มีนบุรี',
#        'district_ยานนาวา', 'district_ราชเทวี', 'district_ราษฎร์บูรณะ',
#        'district_ลาดกระบัง', 'district_ลาดพร้าว', 'district_วังทองหลาง',
#        'district_วัฒนา', 'district_สวนหลวง', 'district_สะพานสูง',
#        'district_สัมพันธวงศ์', 'district_สาทร', 'district_สายไหม',
#        'district_หนองจอก', 'district_หนองแขม', 'district_หลักสี่',
#        'district_ห้วยขวาง'],
#       dtype='object')
