# %%
import pandas as pd

# %%
df = pd.read_csv('data/processed/traffy_weather_merged.csv')

# %%
import sys
sys.path.insert(0, '..')

from pipeline.transform import assign_grid_cells

df_test = df[['latitude', 'longitude']].head(1000).copy()
df_weather_test = pd.DataFrame({
    'latitude': [13.74, 13.60, 13.81],
    'longitude': [100.50, 100.56, 100.51]
})

df_test, df_weather_test = assign_grid_cells(df_test, df_weather_test, delta=0.1)

print("Traffy grid values:")
print(df_test[['latitude', 'longitude', 'grid_lat', 'grid_lon']].head(10))
print("\nWeather grid values:")
print(df_weather_test[['latitude', 'longitude', 'grid_lat', 'grid_lon']])
print("\nUnique Traffy grids:", df_test[['grid_lat', 'grid_lon']].drop_duplicates().values[:10])
print("Unique Weather grids:", df_weather_test[['grid_lat', 'grid_lon']].drop_duplicates().values)
# Out:
# Traffy grid values:
#    latitude  longitude  grid_lat  grid_lon
# 0  13.67891  100.66709      13.7     100.7
# 1  13.72060  100.52649      13.7     100.5
# 2  13.82280  100.59165      13.8     100.6
# 3  13.80910  100.59131      13.8     100.6
# 4  13.77832  100.50848      13.8     100.5
# 5  13.67083  100.64690      13.7     100.6
# 6  13.72812  100.65617      13.7     100.7
# 7  13.68158  100.65440      13.7     100.7
# 8  13.68735  100.64844      13.7     100.6
# 9  13.71887  100.68837      13.7     100.7
#
# Weather grid values:
#    latitude  longitude  grid_lat  grid_lon
# 0     13.74     100.50      13.7     100.5
# 1     13.60     100.56      13.6     100.6
# 2     13.81     100.51      13.8     100.5
#
# Unique Traffy grids: [[ 13.7 100.7]
#  [ 13.7 100.5]
#  [ 13.8 100.6]
#  [ 13.8 100.5]
#  [ 13.7 100.6]
#  [ 13.9 100.6]
#  [ 13.7 100.4]
#  [ 13.8 100.7]
#  [ 13.8 100.9]
#  [ 13.9 100.7]]
# Unique Weather grids: [[ 13.7 100.5]
#  [ 13.6 100.6]
#  [ 13.8 100.5]]
