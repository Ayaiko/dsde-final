# %%
# Reload modules to pick up changes
import importlib
import pipeline.features
import pipeline.preprocess

importlib.reload(pipeline.features)
importlib.reload(pipeline.preprocess)

from pipeline.features import *
from pipeline.preprocess import *

print("✓ Modules reloaded")

# %%
import pandas as pd
from pipeline.features import *
from pipeline.preprocess import parse_type_column

# %%
df = pd.read_csv('data/processed/traffy_weather_merged.csv')

# %%
df = prepare_features(df)
# Out:
# ============================================================
# FEATURE ENGINEERING
# ============================================================
#
# Extracting time features...
# hello
# Encoding cyclical features...
# Encoding districts...
#   ✓ Encoded 50 districts
#
# ✓ Feature engineering complete
#   Final shape: (540633, 134)
#   New features: hour, day_of_week, month, season, cyclical encodings, districts
# hello
# Encoding cyclical features...
# Encoding districts...
#   ✓ Encoded 50 districts
#
# ✓ Feature engineering complete
#   Final shape: (540633, 134)
#   New features: hour, day_of_week, month, season, cyclical encodings, districts

# %%
df.head()
# Out:
#                    type                                            comment  \
# 0  [น้ำท่วม, ร้องเรียน]  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 1               [สะพาน]    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 2        [น้ำท่วม, ถนน]  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 3           [ความสะอาด]                  คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 4         [ท่อระบายน้ำ]  ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
#
#                coords subdistrict  district       province  \
# 0  100.66709,13.67891     หนองบอน    ประเวศ  กรุงเทพมหานคร
# 1  100.52649,13.72060     ยานนาวา      สาทร  กรุงเทพมหานคร
# 2  100.59165,13.82280    ลาดพร้าว  ลาดพร้าว  กรุงเทพมหานคร
# 3  100.64690,13.67083     หนองบอน    ประเวศ  กรุงเทพมหานคร
# 4  100.65440,13.68158     หนองบอน    ประเวศ  กรุงเทพมหานคร
#
#                           timestamp  longitude  latitude  \
# 0  2021-09-19 14:56:08.924992+00:00  100.66709  13.67891
# 1  2021-09-26 05:03:52.594898+00:00  100.52649  13.72060
# 2  2021-12-09 12:29:08.408763+00:00  100.59165  13.82280
# 3  2021-12-18 14:50:52.437512+00:00  100.64690  13.67083
# 4  2021-12-22 10:15:33.294829+00:00  100.65440  13.68158
#
#               timestamp_hour  ...  district_วัฒนา  district_สวนหลวง  \
# 0  2021-09-19 14:00:00+00:00  ...           False             False
# 1  2021-09-26 05:00:00+00:00  ...           False             False
# 2  2021-12-09 12:00:00+00:00  ...           False             False
# 3  2021-12-18 14:00:00+00:00  ...           False             False
# 4  2021-12-22 10:00:00+00:00  ...           False             False
#
#   district_สะพานสูง  district_สัมพันธวงศ์  district_สาทร  district_สายไหม  \
# 0             False                 False          False            False
# 1             False                 False           True            False
# 2             False                 False          False            False
# 3             False                 False          False            False
# 4             False                 False          False            False
#
#    district_หนองจอก  district_หนองแขม  district_หลักสี่  district_ห้วยขวาง
# 0             False             False             False              False
# 1             False             False             False              False
# 2             False             False             False              False
# 3             False             False             False              False
# 4             False             False             False              False
#
# [5 rows x 134 columns]
