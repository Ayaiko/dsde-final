# %%
import pandas as pd

df = pd.read_csv('data/processed/traffy_merged.csv')
print(f"Original: {len(df):,} rows")

half_size = len(df) // 2
df_v1 = df.iloc[:half_size]

df_v1.to_csv('data/processed/traffy_merged_v1.csv', index=False)
print(f"Saved v1: {len(df_v1):,} rows to traffy_merged_v1.csv")
# Out:
# C:\Users\grain\AppData\Local\Temp\ipykernel_8132\3403892773.py:3: DtypeWarning: Columns (8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/processed/traffy_merged.csv')
# Original: 651,600 rows
# Saved v1: 325,800 rows to traffy_merged_v1.csv
# Saved v1: 325,800 rows to traffy_merged_v1.csv
